# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import psycopg
from sqlalchemy import create_engine

# %%
pip install psycopg2
# Out:
# ...
#   Using cached psycopg2-2.9.5.tar.gz (384 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/miriam/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/72/why63qhx3j7891zyvf7x6qsm0000gn/T/pip-install-pnhurjxs/psycopg2_477d5a4da29b4e809dc50e34c2cac829/setup.py'"'"'; __file__='"'"'/private/var/folders/72/why63qhx3j7891zyvf7x6qsm0000gn/T/pip-install-pnhurjxs/psycopg2_477d5a4da29b4e809dc50e34c2cac829/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/72/why63qhx3j7891zyvf7x6qsm0000gn/T/pip-pip-egg-info-37mhke7o
# ...
